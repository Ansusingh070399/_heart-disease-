# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm

# %%
 import pandas as pd
    
df = pd.read_csv('C:\\Users\\ansus\\heart_disease .csv.txt')

# %%
df.head()
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 1   63    1       typical     145   233    1        2    150      0      2.3
# 2   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 3   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 4   37    1    nonanginal     130   250    0        0    187      0      3.5
# 5   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 1      3  0.0       fixed   No
# 2      2  3.0      normal  Yes
# 3      2  2.0  reversable  Yes
# 4      3  0.0      normal   No
# 5      1  0.0      normal   No

# %%
model = sm.GLM.from_formula("AHD ~ Age", family =
sm.families.Binomial(),data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     ['AHD[No]', 'AHD[Yes]']   No. Observations:                  303
# Model:                                 GLM   Df Residuals:                      301
# Model Family:                     Binomial   Df Model:                            1
# Link Function:                       logit   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -201.27
# Date:                     Tue, 14 Sep 2021   Deviance:                       402.54
# Time:                             17:08:37   Pearson chi2:                     303.
# No. Iterations:                          4
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.0059      0.759      3.960      0.000       1.518       4.494
# Age           -0.0520      0.014     -3.803      0.000      -0.079      -0.025
# ==============================================================================
# """

# %%
df["Sex1"] = df.Sex.replace({1:"Male", 0:"Female"})
c = pd.crosstab(df.Sex1, df.AHD)
c = c.apply(lambda x: x/x.sum(), axis=1)

# %%
print(df.isna().sum())
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# Sex1         0
# dtype: int64

# %%
model = sm.GLM.from_formula("AHD ~ Sex1", family =
sm.families.Binomial(), data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     ['AHD[No]', 'AHD[Yes]']   No. Observations:                  303
# Model:                                 GLM   Df Residuals:                      301
# Model Family:                     Binomial   Df Model:                            1
# Link Function:                       logit   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -196.97
# Date:                     Tue, 14 Sep 2021   Deviance:                       393.93
# Time:                             17:08:37   Pearson chi2:                     303.
# No. Iterations:                          4
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        1.0578      0.232      4.557      0.000       0.603       1.513
# Sex1[T.Male]    -1.2722      0.271     -4.692      0.000      -1.804      -0.741
# ================================================================================
# """

# %%
import c
df["Sex1"] = df.Sex.replace({1:"Male", 0:"Female"})
c = pd.crosstab(df.Sex1, df.AHD)
c = c.apply(lambda x: x/x.sum(), axis=1)

# %%
model = sm.GLM.from_formula("AHD ~ Age + Sex1", family =
sm.families.Binomial(), data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     ['AHD[No]', 'AHD[Yes]']   No. Observations:                  303
# Model:                                 GLM   Df Residuals:                      300
# Model Family:                     Binomial   Df Model:                            2
# Link Function:                       logit   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -186.15
# Date:                     Tue, 14 Sep 2021   Deviance:                       372.31
# Time:                             17:08:37   Pearson chi2:                     298.
# No. Iterations:                          4
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        4.8077      0.898      5.353      0.000       3.047       6.568
# Sex1[T.Male]    -1.4989      0.289     -5.179      0.000      -2.066      -0.932
# Age             -0.0657      0.015     -4.427      0.000      -0.095      -0.037
# ================================================================================
# """

# %%
model = sm.GLM.from_formula("AHD ~ Age + Sex1 + Chol", family =
sm.families.Binomial(), data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     ['AHD[No]', 'AHD[Yes]']   No. Observations:                  303
# Model:                                 GLM   Df Residuals:                      299
# Model Family:                     Binomial   Df Model:                            3
# Link Function:                       logit   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -184.30
# Date:                     Tue, 14 Sep 2021   Deviance:                       368.59
# Time:                             17:08:37   Pearson chi2:                     295.
# No. Iterations:                          4
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        5.9094      1.095      5.395      0.000       3.762       8.056
# Sex1[T.Male]    -1.6318      0.303     -5.382      0.000      -2.226      -1.038
# Age             -0.0622      0.015     -4.117      0.000      -0.092      -0.033
# Chol            -0.0048      0.003     -1.902      0.057      -0.010       0.000
# ================================================================================
# """

# %%
df[['Age', 'Sex','Chol']].corr()
# Out:
#            Age       Sex      Chol
# Age   1.000000 -0.097542  0.208950
# Sex  -0.097542  1.000000 -0.199915
# Chol  0.208950 -0.199915  1.000000

# %%
import numpy as np
pr1 = 1 / (1 + np.exp(-pr))
cb1 = 1 / (1 + np.exp(-cb))
ax = sns.lineplot(fv, pr1, lw=4)
ax.fill_between(fv, cb1[:, 0], cb[:, 1], "grey", alpha=0.4)
ax.set_xlabel("Age", size=15)
ax.set_ylabel("Heart Disease")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c705b99fa1f5> in <module>
#       1 import numpy as np
# ----> 2 pr1 = 1 / (1 + np.exp(-pr))
#       3 cb1 = 1 / (1 + np.exp(-cb))
#       4 ax = sns.lineplot(fv, pr1, lw=4)
#       5 ax.fill_between(fv, cb1[:, 0], cb[:, 1], "grey", alpha=0.4)
#
# NameError: name 'pr' is not defined

# %%
from statsmodels.graphics.regressionplots import add_lowess
fig = result.plot_partial_residuals("Age")
ax = fig.get_axes()[0]
ax.lines[0].set_alpha(0.5)
_ = add_lowess(ax)

# %%
df['ChestPain'] = df.ChestPain.replace({"typical":1, "asymptomatic": 2, 'nonanginal': 3, 'nontypical':4})
df['Thal'] = df.Thal.replace({'fixed': 1, 'normal': 2, 'reversable': 3})
df[['Age', 'Sex1', 'Chol','RestBP', 'Fbs', 'RestECG', 'Slope', 'Oldpeak', 'Ca', 'ExAng', 'ChestPain', 'Thal']].corr()
# Out:
#                 Age      Chol    RestBP       Fbs   RestECG     Slope  \
# Age        1.000000  0.208950  0.284946  0.118530  0.148868  0.161770
# Chol       0.208950  1.000000  0.130120  0.009841  0.171043 -0.004062
# RestBP     0.284946  0.130120  1.000000  0.175340  0.146560  0.117382
# Fbs        0.118530  0.009841  0.175340  1.000000  0.069564  0.059894
# RestECG    0.148868  0.171043  0.146560  0.069564  1.000000  0.133946
# Slope      0.161770 -0.004062  0.117382  0.059894  0.133946  1.000000
# Oldpeak    0.203805  0.046564  0.189171  0.005747  0.114133  0.577537
# Ca         0.362605  0.119000  0.098773  0.145478  0.128343  0.110119
# ExAng      0.091661  0.061310  0.064762  0.025665  0.084867  0.257748
# ChestPain -0.173124 -0.015387 -0.145149 -0.023976 -0.157005 -0.250500
# Thal       0.061823  0.080874  0.057602 -0.007605 -0.011543  0.106051
#
#             Oldpeak        Ca     ExAng  ChestPain      Thal
# Age        0.203805  0.362605  0.091661  -0.173124  0.061823
# Chol       0.046564  0.119000  0.061310  -0.015387  0.080874
# RestBP     0.189171  0.098773  0.064762  -0.145149  0.057602
# Fbs        0.005747  0.145478  0.025665  -0.023976 -0.007605
# RestECG    0.114133  0.128343  0.084867  -0.157005 -0.011543
# Slope      0.577537  0.110119  0.257748  -0.250500  0.106051
# Oldpeak    1.000000  0.295832  0.288223  -0.334661  0.208998
# Ca         0.295832  1.000000  0.145570  -0.187667  0.149768
# ExAng      0.288223  0.145570  1.000000  -0.314993  0.228084
# ChestPain -0.334661 -0.187667 -0.314993   1.000000 -0.168103
# Thal       0.208998  0.149768  0.228084  -0.168103  1.000000

# %%
model = sm.GLM.from_formula("AHD ~ Age + Sex1 + Chol + RestBP+ Fbs + RestECG + Slope + Oldpeak + Ca + ExAng + ChestPain + Thal", family = sm.families.Binomial(), data=df)
result = model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     ['AHD[No]', 'AHD[Yes]']   No. Observations:                  297
# Model:                                 GLM   Df Residuals:                      284
# Model Family:                     Binomial   Df Model:                           12
# Link Function:                       logit   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -113.49
# Date:                     Tue, 14 Sep 2021   Deviance:                       226.99
# Time:                             17:35:39   Pearson chi2:                     287.
# No. Iterations:                          6
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        9.0184      2.167      4.162      0.000       4.771      13.266
# Sex1[T.Male]    -1.3765      0.426     -3.230      0.001      -2.212      -0.541
# Age             -0.0052      0.021     -0.245      0.807      -0.047       0.037
# Chol            -0.0041      0.004     -1.160      0.246      -0.011       0.003
# RestBP          -0.0165      0.010     -1.621      0.105      -0.036       0.003
# Fbs              1.0297      0.507      2.031      0.042       0.036       2.024
# RestECG         -0.2011      0.173     -1.164      0.244      -0.540       0.138
# Slope           -0.7875      0.336     -2.343      0.019      -1.446      -0.129
# Oldpeak         -0.2789      0.205     -1.361      0.174      -0.681       0.123
# Ca              -1.3120      0.247     -5.301      0.000      -1.797      -0.827
# ExAng           -1.4776      0.372     -3.976      0.000      -2.206      -0.749
# ChestPain        0.2524      0.205      1.234      0.217      -0.149       0.653
# Thal            -0.9276      0.282     -3.285      0.001      -1.481      -0.374
# ================================================================================
# """

# %%
X = df[['Age', 'Sex1', 'Chol','RestBP', 'Fbs', 'RestECG', 'Slope', 'Oldpeak', 'Ca', 'ExAng', 'ChestPain', 'Thal']]
predicted_output = result.predict(X)

# %%
corr = df.corr()
plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
sns.heatmap(corr, xticklabels=corr.columns,
            yticklabels=corr.columns, 
            annot=True,
            cmap=sns.diverging_palette(220, 20, as_cmap=True))
# Out:
# <AxesSubplot:>

# %%
subDf = df[['Age','RestBP','Chol','MaxHR','Ca']]
sns.pairplot(subDf)
